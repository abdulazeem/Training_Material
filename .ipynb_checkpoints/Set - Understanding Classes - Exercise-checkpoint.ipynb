# %% [markdown]
# # What is a Class?
#
# A class is a user-defined blueprint or prototype from which objects are created. Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Exercise 1: Instantiate Class Turtle
#
# 1) Write a simple function to draw a line using class Turtle.
#
# 2) Understand Turtle Documentation:https://docs.python.org/3/library/turtle.html

# %% [markdown]
# # Exercise 2:Draw a Square using Class Turtle
#
# 1) Create an instance of class turtle to create a square.
#
# 2) Use shape, color, speed methods to modify the turtle

# %% [markdown]
#  # Exercise 3: Draw a Circle Using Class turtle

# %% [markdown]
# # Exercise 5: Draw the following figure using class Turtle
#
# ![image.png](attachment:image.png)
