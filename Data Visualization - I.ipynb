# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
data=pd.read_csv('women_education.csv')
data.head(5)
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
# 1  64.556485               73.9                75.5                 39.0
# 2  63.664263               74.6                76.9                 40.2
# 3  62.941502               74.9                77.4                 40.9
# 4  62.413412               75.3                77.9                 41.8
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
# 1               14.9        46.2                   65.5
# 2               14.8        47.6                   62.6
# 3               16.5        50.4                   64.3
# 4               18.2        52.6                   66.1
#
#    Social Sciences and History
# 0                         36.8
# 1                         36.2
# 2                         36.1
# 3                         36.4
# 4                         37.3

# %%
import os
os.chdir(r'C:\Users\user\Desktop\DS - Course\File - 7')

# %% [markdown]
# # Exercise 1: Basics of Matplotlib
#
# 1) Import a dataset and create the following plots
#
#     a) Line plot  - plt.plot(x,y ,color, marker, linestyle)
#
#     b) Box plot - plt.boxplot(x)
#
#     c) Two-dimensional scatter plot - plt.scatter(x,y ,color, marker, linestyle)
#
# 2) Plot the labels using plt.xlabel, plt.ylabel, plt.title
#
# Use women_education.csv

# %%
# a) Line plot  - plt.plot(x,y ,color, marker, linestyle)
import matplotlib.pyplot as plt

plt.plot(data['Year'], data['Agriculture'], color='green', marker='o', linestyle='dashed')

plt.xlabel('Year')

plt.ylabel('Agriculture')
plt.title('Women Graduates in Agriculture')
# Out:
# Text(0.5, 1.0, 'Women Graduates in Agriculture')

# %%
# b)Box plot

plt.boxplot(data['Engineering'], showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x166b35a0588>,
#   <matplotlib.lines.Line2D at 0x166b35a0d48>],
#  'caps': [<matplotlib.lines.Line2D at 0x166b35c55c8>,
#   <matplotlib.lines.Line2D at 0x166b35c59c8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x166b35a0bc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x166b34fb1c8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x166b1836288>],
#  'means': [<matplotlib.lines.Line2D at 0x166b34fbd88>]}

# %%
df=pd.read_csv('auto_mpg.csv')
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %%
# c) Two-dimensional scatter plot

plt.scatter(df['hp'], df['mpg'], color='green', marker='o', linestyle='dashed')

# %%
# graph using axes() command

# %% [markdown]
# # Exercise 2: Multiple plots on single axis
#
# We have women_education.csv data consisting of records of degrees awarded to women in a variety of fields from 1970 to 2011.
#
# 1) Create Multiple plots on single figure
#
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html

# %%
edu = pd.read_csv('women_education.csv')
edu.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
#      English  Foreign Languages  Health Professions  Math and Statistics  \
# 0  65.570923               73.8                77.1                 38.0
# 1  64.556485               73.9                75.5                 39.0
# 2  63.664263               74.6                76.9                 40.2
# 3  62.941502               74.9                77.4                 40.9
# 4  62.413412               75.3                77.9                 41.8
#
#    Physical Sciences  Psychology  Public Administration  \
# 0               13.8        44.4                   68.4
# 1               14.9        46.2                   65.5
# 2               14.8        47.6                   62.6
# 3               16.5        50.4                   64.3
# 4               18.2        52.6                   66.1
#
#    Social Sciences and History
# 0                         36.8
# 1                         36.2
# 2                         36.1
# 3                         36.4
# 4                         37.3

# %%
# 1) Multiple plots on single figure
year = edu['Year']

psych = edu['Psychology']
puadm = edu['Public Administration']
cse = edu['Computer Science']
eng = edu['English']

plt.plot(year,psych, color='blue')
plt.plot(year, puadm, color = 'red')
plt.plot(year, cse, color = 'cyan')

plt.xlabel('Year')
plt.ylabel('Subject')
plt.title('Graduation per year')

plt.show()

# %% [markdown]
# # Exercise 3: Using Axes ()
#
# Instead of plotting multiple plots on single figure, we can plot different line plots on distinct axes. One of the ways to do this is by using plt.axes() function.
#
# In calling plt.axes([xlo, ylo, width, height]), a set of axes is created and made active with lower corner at coordinates (xlo, ylo) of the specified width and height. Note that these coordinates can be passed to plt.axes() in the form of a list or a tuple.
#
# The coordinates and lengths are values between 0 and 1 representing lengths relative to the dimensions of the figure. After issuing a plt.axes() command, plots generated are put in that set of axes.
#
# - Create Separate plots for each using .axes()

# %%
# Create axes for first plot

plt.axes([0.05, 0.05, 0.4, 0.9])

plt.plot(year,psych, color='blue')

# Create axes for second plot
plt.axes([0.55, 0.05, 0.4, 0.9])
plt.plot(year, cse, color = 'red')

plt.show()

# %% [markdown]
# # Exercise 4: Using subplot()
#
# plt.subplot(m, n, k) to make the subplot grid of dimensions m by n and to make the kth subplot active (subplots are numbered starting from 1 row-wise from the top left corner of the subplot grid).
#
# https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.subplot.html
#
# 1) Create a 1 x 2 subplot layout and plot the Psychology and Computer Science in different plots.
#
# 2) Create a 2 x 2 subplot layout and plot Psychology, Computer Science, Agriculture and Arts in various supplots.

# %%
# 1) Create a 1 x 2 subplot layout and plot the Psychology and Computer Science in different plots

plt.subplot(1, 2, 1)
plt.plot(year,psych, color='blue')

plt.title('Psychology')

plt.subplot(1,2,2)
plt.plot(year, cse, color = 'cyan')

plt.title('Computer Science')

plt.tight_layout()
plt.show()

# %%
# 2) Create a 2 x 2 subplot layout and plot Psychology, Computer Science, Agriculture and Arts in various supplots.

plt.subplot(2, 2, 1) 

plt.plot(year, psych, color='blue')
plt.title('Psychology')


plt.subplot(2, 2, 2)

plt.plot(year, puadm, color='red')
plt.title('Public Administration')


plt.subplot(2, 2, 3)

plt.plot(year, cse, color='green')
plt.title('Computer Science')


plt.subplot(2, 2, 4)


plt.plot(year, eng, color='yellow')
plt.title('English')

# Improve the spacing between subplots and display them
plt.tight_layout()
plt.show()

# %% [markdown]
# # Exercise 5: Controlling Axis Extents and Savefig
#
# Controlling axis extents using xlim and ylim. Optionally we can use .axis
#
# 1) Zoom out the Pyhysical Sciences plt.xlim() and plt.ylim() for the years 1990 and 2010. Also save the figure using plt.savefig
#
# 2) Repeate the same using plt.axis()
#
# https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.axis.html

# %%
# Plot the % of degrees awarded to women in Computer Science and the Physical Sciences

ps = edu['Physical Sciences']
plt.plot(year,cse, color='red') 
plt.plot(year, ps, color='blue')

plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

#plt.xlim(1990,2010) 

#plt.ylim(0,50)

plt.axis([1990, 2010, 0, 50])

plt.title('Degrees awarded to women (1990-2010)')
plt.show()


plt.savefig('xlim_and_ylim.png')

# %% [markdown]
# # Exercise 5: Legends
#
# Plot two columns from the women graduation data with labels, and create a legend using plt.legend(loc='')
#
# ![image.png](attachment:image.png)

# %%
plt.plot(year, cse, color='red', label='Computer Science')

plt.plot(year, ps, color ='blue', label ='Physical Science')

plt.legend(loc='lower center')

plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate Women Enrollment')
plt.show()

# %% [markdown]
# # Exercise 7: Annotate and Styleguide
#
# It is often useful to annotate a simple plot to provide context. This makes the plot more readable and can highlight specific aspects of the data. Annotations like text and arrows can be used to emphasize specific observations.
#
# 1) Use plt.annotate to highlight the maximum enrollment in computer science, physical sciences plot.
#
# plt.annotate(label, xy, xytext, arrowprops=dict(facecolor))
#
# 2) Check the available styleguides using plt.style.available and use anyone using plt.style.use()
#
# ![image.png](attachment:image.png)
#
# https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.annotate.html

# %%
# Check available styleguides
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
# 1) Use plt.annotate to highlight the maximum enrollment in computer science, physical sciences plot.

pse = edu['Physical Sciences']
max_enrol = pse.max()
yr_max = year[pse.idxmax()]

max_enrolc=cse.max()
yr_maxc = year[cse.idxmax()]

plt.style.use('ggplot')

plt.plot(year, cse, color='red', label='Computer Science')

plt.plot(year, ps, color ='blue', label ='Physical Science')

plt.annotate('Maximum - Physical Science', xy=(yr_max, max_enrol), xytext = (yr_max+5, max_enrol+5), arrowprops=dict(facecolor='black'))

plt.annotate('Maximum - Computer Science', xy=(yr_maxc, max_enrolc), xytext = (yr_maxc+5, max_enrolc+5), arrowprops=dict(facecolor='green'))

plt.legend(loc='lower center')
